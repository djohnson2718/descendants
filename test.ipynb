# %%
load("dec_series.sage")

# %%
D = dec_series(2,1)

# %%
D

# %%
D.qiffy_poly(g1+g2)
# Out:
# (q - 1)^-1 * q

# %%
D.qiffy_poly(g1*g2)
# Out:
# (-2) * (q - 1)^-1 * q

# %%
(-1/2*g1^3/(g1*(q - 1) - q)).parent()
# Out:
# Symbolic Ring

# %%
D.Fg("(-1/2*g1^3/(g1*(q - 1) - q))")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-127-2f7167526fa6> in <module>()
# ----> 1 D.Fg("(-1/2*g1^3/(g1*(q - 1) - q))")
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/parent.pyx in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:9237)()
#     887         if mor is not None:
#     888             if no_extra_args:
# --> 889                 return mor._call_(x)
#     890             else:
#     891                 return mor._call_with_args(x, args, kwds)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/coerce_maps.pyx in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:4658)()
#     160                 print(type(C), C)
#     161                 print(type(C._element_constructor), C._element_constructor)
# ...

# %%
(-1/2*g1^3/(g1*(q - 1) - q)) in D.Rg
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-122-76cab247270c> in <module>()
# ----> 1 (-Integer(1)/Integer(2)*g1**Integer(3)/(g1*(q - Integer(1)) - q)) in D.Rg
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/parent.pyx in sage.structure.parent.Parent.__contains__ (build/cythonized/sage/structure/parent.c:9885)()
#    1079             return True
#    1080         try:
# -> 1081             x2 = self(x)
#    1082             EQ = (x2 == x)
#    1083             if EQ is True:
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/rings/polynomial/multi_polynomial_ring.pyc in __call__(self, x, check)
#     526
#     527         elif hasattr(x, '_polynomial_'):
# --> 528             return x._polynomial_(self)
#     529
#     530         elif isinstance(x, str):
#
# ...

# %%
(-1/2*g1^3/(g1*(q - 1) - q) ) in D.Rg
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-115-3371e5216a84> in <module>()
# ----> 1 (-Integer(1)/Integer(2)*g1**Integer(3)/(g1*(q - Integer(1)) - q) ) in D.Rg
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/parent.pyx in sage.structure.parent.Parent.__contains__ (build/cythonized/sage/structure/parent.c:9885)()
#    1079             return True
#    1080         try:
# -> 1081             x2 = self(x)
#    1082             EQ = (x2 == x)
#    1083             if EQ is True:
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/rings/polynomial/multi_polynomial_ring.pyc in __call__(self, x, check)
#     526
#     527         elif hasattr(x, '_polynomial_'):
# --> 528             return x._polynomial_(self)
#     529
#     530         elif isinstance(x, str):
#
# ...

# %%
D.qiffy_diff(g1+g2,[x])
# Out:
# x
# done
# done with loop -g1^3/(3*g1^2*x + 2*g1*(q - 1) - 2*q) - g2^3/(3*g2^2*x + 2*g2*(q - 1) - 2*q)
# done with subs -1/2*g1^3/(g1*(q - 1) - q) - 1/2*g2^3/(g2*(q - 1) - q)
# entered qiffy
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-109-cacac3ae0f2c> in <module>()
# ----> 1 D.qiffy_diff(g1+g2,[x])
#
# <string> in qiffy_diff(self, f, dlist)
#
# <string> in qiffy_frac(self, f)
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/structure/parent.pyx in sage.structure.parent.Parent.__contains__ (build/cythonized/sage/structure/parent.c:9885)()
#    1079             return True
#    1080         try:
# -> 1081             x2 = self(x)
#    1082             EQ = (x2 == x)
#    1083             if EQ is True:
#
# /opt/sagemath-8.6/local/lib/python2.7/site-packages/sage/rings/polynomial/multi_polynomial_ring.pyc in __call__(self, x, check)
#     526
# ...

# %%
Fg
